# %% [markdown]
# # Saloni Patel (A4-4.5-Data Consistency Checks)

# %% [markdown]
# # Importing Libraries and Data

# %% [markdown]
# ### Importing Libraries

# %%
# importing libraries

import pandas as pd
import numpy as np
import os

# %%
# Creating Path for ease of code

path = r'C:\Users\psalo\OneDrive\Study\CF - DA Immersion\A4 - Python Fundamentals for Data Analyst\A4 - Instacart Basket Analysis 07-2025'

# %% [markdown]
# ### Importing Product Original Data

# %%
# Importing Product Data from Original Data Folder

df_prod = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '4.3_orders_products' , 'products.csv'), index_col = False)

# %% [markdown]
# ### Importing Order Prepared Data

# %%
# Importing Order Data from Prepared Data Folder

df_ord = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)
print(f"Number of rows imported: {df_ord.shape[0]}")
# Out:
# Number of rows imported: 3421083

# %% [markdown]
# ### Importing Department Prepared Data

# %%
#Importing Department data from Prepared Data Folder

df_deptnew = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'), index_col = False)

# %% [markdown]
# ### Checking the imported data

# %%
df_ord.info
# Out:
# <bound method DataFrame.info of          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_last_order
# 0                         2                  8                    NaN
# 1                         3                  7                   15.0
# 2                         3                 12                   21.0
# 3                         4                  7                   29.0
# 4                         4                 15                   28.0
# ...                     ...                ...                    ...
# 3421078                   5                 18                   29.0
# 3421079                   4                 10                   30.0
# 3421080                   1                 12                   18.0
# 3421081                   1                 12                    7.0
# 3421082                   6                 14                   30.0
#
# [3421083 rows x 8 columns]>

# %%
df_prod.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_deptnew
# Out:
#     Unnamed: 0       department
# 0            1           frozen
# 1            2            other
# 2            3           bakery
# 3            4          produce
# 4            5          alcohol
# 5            6    international
# 6            7        beverages
# 7            8             pets
# 8            9  dry goods pasta
# 9           10             bulk
# 10          11    personal care
# 11          12     meat seafood
# 12          13           pantry
# 13          14        breakfast
# 14          15     canned goods
# 15          16       dairy eggs
# 16          17        household
# 17          18           babies
# 18          19           snacks
# 19          20             deli
# 20          21          missing

# %% [markdown]
# # A4 - 4.5 - Practice

# %% [markdown]
# ### Mix Data Types

# %%
# Creating a test df

df_test = pd.DataFrame()

# %%
# Creating a new column in test df

df_test['mix'] = ['a', 'b', 1, True]

# %%
# lets see how new test df looks

df_test
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# checking if df contains any column with mix values

for col in df_test.columns.tolist():
  weird = (df_test[[col]].map(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
# change the data type of mix column to str

df_test['mix'] = df_test['mix'].astype('str')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mix     4 non-null      object
# dtypes: object(1)
# memory usage: 164.0+ bytes

# %% [markdown]
# ### Missing Data

# %%
# looking for null values in df_prod

df_prod.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# creating a subset with all null values

df_nan = df_prod[df_prod['product_name'].isnull() == True]

# %%
# lets see what df_nan looks like. It should have 16 rows

df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# 38187       38183          NaN        39             12    20.9
# 40444       40440          NaN       120             16    14.8

# %%
# median of the df_prod

median_value = df_prod['product_name'].mode()

# %%
df_prod['product_name'].fillna(median_value, inplace=True)
# Out:
# C:\Users\psalo\AppData\Local\Temp\ipykernel_16204\1005008731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_prod['product_name'].fillna(median_value, inplace=True)

# %%
df_prod.shape
# Out:
# (49693, 5)

# %%
# creating a subset with clean data

df_prod_clean = df_prod[df_prod['product_name'].isnull() == False]

# %%
# check out the subset

df_prod_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# 2            94              7     4.5
# 3            38              1    10.5
# 4             5             13     4.3
# ...         ...            ...     ...
# 49688       124              5     5.3
# 49689        42              1     3.1
# 49690       112              3     7.8
# 49691        41              8     4.7
# 49692        73             11    13.5
#
# [49677 rows x 5 columns]

# %% [markdown]
# ### Duplicate Data

# %%
# creating a subset for duplicates

df_dups = df_prod_clean[df_prod_clean.duplicated()]

# %%
# checking the duplicate subset to see how many rows are in that subset 

df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# checking the stats of the df_dup

df_dups.shape
# Out:
# (5, 5)

# %%
# checking the stats of the df_prod_clean

df_prod_clean.shape
# Out:
# (49677, 5)

# %%
# dropping duplicates 

df_prod_clean_no_dups = df_prod_clean.drop_duplicates()

# %%
# checking the stats of the df_prod_clean_no_dups . it should have 5 less rows than df_prod_clean

df_prod_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# ### Exporting df_prod_clean_no_dups as a Product_cleaned.csv in Prepared Data section

# %%
# exporting product data in Prepared folder

df_prod_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Products_cleaned.csv'))

# %% [markdown]
# # A4 - 4.5 - Assignment

# %% [markdown]
# ### 2 - Run the df.describe() function on your df_ords dataframe. Using your new knowledge about how to interpret the output of this function, share in a markdown cell whether anything about the data looks off or should be investigated further.
# Tip: Keep an eye on min and max values!
#
# 1. User_id, Order_id and order_number are irrelevant to this purpose.
# 2. Values for Orders_day_of_week is between 0 and 6 which is right.
# 3. Order_hour_of_day has lowest value of 0 and highest value of 23 which is expected.

# %%
# describe on df_ord

df_ord.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_last_order
# count        3.421083e+06       3.421083e+06           3.214874e+06
# mean         2.776219e+00       1.345202e+01           1.111484e+01
# std          2.046829e+00       4.226088e+00           9.206737e+00
# min          0.000000e+00       0.000000e+00           0.000000e+00
# 25%          1.000000e+00       1.000000e+01           4.000000e+00
# 50%          3.000000e+00       1.300000e+01           7.000000e+00
# 75%          5.000000e+00       1.600000e+01           1.500000e+01
# max          6.000000e+00       2.300000e+01           3.000000e+01

# %% [markdown]
# ### 3 - Check for mixed-type data in your df_ord dataframe.
#
# There are no mixed-type variables in the df_ord

# %%
# checking if df_ord contains any column with mix values

for col in df_ord.columns.tolist():
  weird = (df_ord[[col]].map(type) != df_ord[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ord[weird]) > 0:
    print (col)

# %%
# I took help of Gemini to see if this code can be better understood and it came up with the following

for col in df_ord.columns:
    types = df_ord[col].apply(type)
    if types.nunique() > 1:
        print(col)

# %% [markdown]
# ### 4 - If you find mixed-type data, fix it. The column in question should contain observations of a single data type.
#
# No mixed-type variables are found in df_ord

# %% [markdown]
# ### 5 - Run a check for missing values in your df_ords dataframe.
# In a markdown cell, report your findings and propose an explanation for any missing values you find.
#
# 1. All columns excet days_since_last_order do not have missing values.
# 2. days_since_last_order has 206,209 missing values as it is indicating the beginning of the customer lifecycle.

# %%
# looking for null values in df_ord

df_ord.isnull().sum()
# Out:
# Unnamed: 0                    0
# order_id                      0
# user_id                       0
# eval_set                      0
# order_number                  0
# orders_day_of_week            0
# order_hour_of_day             0
# days_since_last_order    206209
# dtype: int64

# %% [markdown]
# ### 6 - Address the missing values using an appropriate method.
# In a markdown cell, explain why you used your method of choice.

# %%
# creating a subset with all the missing values from col. 'days_since_last_order'

df_ord_nan = df_ord[df_ord['days_since_last_order'].isnull() == True]

# %%
# lets see the subset. It has 206209 rows with NaN in days_since_last_order column

df_ord_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_week  order_hour_of_day  days_since_last_order
# 0                         2                  8                    NaN
# 11                        2                 11                    NaN
# 26                        1                 14                    NaN
# 39                        6                 11                    NaN
# 45                        3                 12                    NaN
# ...                     ...                ...                    ...
# 3420930                   4                 12                    NaN
# 3420934                   3                 18                    NaN
# 3421002                   6                 19                    NaN
# 3421019                   1                 15                    NaN
# 3421069                   3                 11                    NaN
#
# [206209 rows x 8 columns]

# %%
#lets replace the missing value NaN with 7 as 50% of the records have 7 as the value for this variable

df_ord['days_since_last_order'].fillna(7, inplace=True)
# Out:
# C:\Users\psalo\AppData\Local\Temp\ipykernel_4592\438755366.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ord['days_since_last_order'].fillna(7, inplace=True)

# %%
df_ord
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_last_order
# 0                         2                  8                    7.0
# 1                         3                  7                   15.0
# 2                         3                 12                   21.0
# 3                         4                  7                   29.0
# 4                         4                 15                   28.0
# ...                     ...                ...                    ...
# 3421078                   5                 18                   29.0
# 3421079                   4                 10                   30.0
# 3421080                   1                 12                   18.0
# 3421081                   1                 12                    7.0
# 3421082                   6                 14                   30.0
#
# [3421083 rows x 8 columns]

# %%
#checking if the change has been done

df_ord.info
# Out:
# <bound method DataFrame.info of          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_last_order
# 0                         2                  8                    7.0
# 1                         3                  7                   15.0
# 2                         3                 12                   21.0
# 3                         4                  7                   29.0
# 4                         4                 15                   28.0
# ...                     ...                ...                    ...
# 3421078                   5                 18                   29.0
# 3421079                   4                 10                   30.0
# 3421080                   1                 12                   18.0
# 3421081                   1                 12                    7.0
# 3421082                   6                 14                   30.0
#
# [3421083 rows x 8 columns]>

# %%
# all order_number with 1 as a value should have 7 as days_since_last_order 

df_ord[df_ord['order_number']==1]
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_week  order_hour_of_day  days_since_last_order
# 0                         2                  8                    7.0
# 11                        2                 11                    7.0
# 26                        1                 14                    7.0
# 39                        6                 11                    7.0
# 45                        3                 12                    7.0
# ...                     ...                ...                    ...
# 3420930                   4                 12                    7.0
# 3420934                   3                 18                    7.0
# 3421002                   6                 19                    7.0
# 3421019                   1                 15                    7.0
# 3421069                   3                 11                    7.0
#
# [206209 rows x 8 columns]

# %% [markdown]
# ### 7 - Run a check for duplicate values in your df_ords data.
# In a markdown cell, report your findings and propose an explanation for any duplicate values you find.
#
# 1. There are no duplicates in this order dataset.

# %%
# creating a subset with clean order data

df_ord_clean = df_ord[df_ord['days_since_last_order'].isnull() == False]

# %%
# lets see the subset with clean order data

df_ord_clean
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_last_order
# 0                         2                  8                    7.0
# 1                         3                  7                   15.0
# 2                         3                 12                   21.0
# 3                         4                  7                   29.0
# 4                         4                 15                   28.0
# ...                     ...                ...                    ...
# 3421078                   5                 18                   29.0
# 3421079                   4                 10                   30.0
# 3421080                   1                 12                   18.0
# 3421081                   1                 12                    7.0
# 3421082                   6                 14                   30.0
#
# [3421083 rows x 8 columns]

# %%
# creating a subset for order data duplicates

df_ord_dups = df_ord_clean[df_ord_clean.duplicated()]

# %%
# checking the duplicate subset to see how many rows are in that subset 

df_ord_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_last_order]
# Index: []

# %% [markdown]
# ### 8 - Address the duplicates using an appropriate method.
#
# NO action required as there are no duplicates in df_ord

# %% [markdown]
# ### 9 - Exporting the cleaned orders data into cvs. I have already exported produt data.

# %%
df_ord.shape
# Out:
# (3421083, 8)

# %%
# exporting cleaned order data in Prepared folder

num_rows = len(df_ord)  
print(f"{num_rows} rows exported to CSV.")

df_ord.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Orders_cleaned.csv'))
# Out:
# 3421083 rows exported to CSV.
